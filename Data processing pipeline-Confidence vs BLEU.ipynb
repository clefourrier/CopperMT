# %%
import os
import itertools
from collections import defaultdict
import re
import math
import sacrebleu
from numpy import cov

# %%
from scipy.stats import pearsonr

# %%
import pandas as pd
from functools import reduce
import operator

# %%
# Adding module to sys path
import sys
sys.path.append("/home/cfourrie/documents/software/public/CopperMT/")
# RNN imports
import pipeline
import torch, numpy as np
from fairseq import checkpoint_utils, data, options, tasks
from pipeline.neural_translation.multilingual_rnns.multilingual_rnn import MultilingualRNNModel

# %%
bleu = sacrebleu.corpus_bleu(["a a"], [["a a"]])
print(bleu)
# Out:
# BLEU = 0.00 100.0/100.0/0.0/0.0 (BP = 1.000 ratio = 1.000 hyp_len = 2 ref_len = 2)

# %%
copper_dir = "/home/cfourrie/documents/software/public/CopperMT/"
raw_data_path = "inputs/raw_data/" 
split_data_path = "inputs/split_data/"

# %%
folders = ["abrahammonpa", "allenbai", "backstromnorthernpakistan", "castrosui", "davletshinaztecan", 
           "felekesemitic", "hantganbangime", "hattorijaponic", "listsamplesize", "mannburmish"]
splits = ["0.10", "0.20", "0.30", "0.40", "0.50"]
models = ["baseline", "BiNMT", "MNMT", "SMT"]
train_name = "training"
test_in_name = "test"
test_out_name = "solutions"
save_as = "results"

# %%
models_dir = "/home/cfourrie/documents/software/public/CopperMT/workspace"

# %%
long2short_castrosui = {'AntangWesternSandong': 'Antang', 'BanliangYangAn': 'Banliang', 'DujiangEasternSandong': 'Dujiang', 'JiaoliPandong': 'Jiaoli', 'JiarongSouthernSandong': 'Jiarong', 'JiuqianSouthernSandong': 'Jiuqian', 'Pandong': 'Pandong', 'RenliEasternSandong': 'Renli', 'SanjiangEasternSandong': 'Sanjiang', 'ShuigenCentralSandong': 'Shuigen', 'ShuiweiSouthernSandong': 'Shuiwei', 'ShuiyaoSouthernSandong': 'Shuiyao', 'TangnianYangAn': 'Tangnian', 'TangzhouWesternSandong': 'Tangzhou', 'TingpaiWesternSandong': 'Tingpai', 'ZhongheCentralSandong': 'Zhonghe'}

# %% [markdown]
# ## Utils

# %%
def sublist_with_unk(ls_with_unk, ls):
    ls = "".join(ls)
    ls_with_unk = "".join(ls_with_unk)
    
    for item in ls_with_unk.split("<unk>"):
        if item not in ls:
            return False

    return True

# %%
def get_neural_bleu_predictions(path, l_in, l_out, n_best):
    # Storage
    source = []
    target = []
    prediction = []
    confidence = []
    cur_prediction = []
    cur_confidence = []
    indices = []
    with open(
            f'{path}/bleu/bleu_checkpoint_best_{l_in}-{l_out}.{l_out}', 'r') as file:
        for i, line in enumerate(file):
            line = line.split("\t")
            # Actual source
            if "S-" in line[0]:
                word = line[1].strip(' ').split()
                source.append(word)
                indices.append(line[0])
                # We reinitialize the cur_prediction list
                if len(cur_prediction) > 0:
                    prediction.append(cur_prediction)
                    confidence.append(cur_confidence)
                    cur_prediction = []
                    cur_confidence = []
            # Actual target
            if "T-" in line[0]:
                word = line[1].strip(' ').split()
                target.append(word)
            # Hypothesis
            if "H-" in line[0] and len(cur_prediction) < n_best:
                word = line[2].strip(' ').split()
                cur_prediction.append(word)
                cur_confidence.append(math.exp(float(line[1])))
        prediction.append(cur_prediction)
        confidence.append(cur_confidence)
        try:
            prediction = [[bor[n] for bor in prediction] for n in range(n_best)]
        except IndexError as e:
            raise e

        #prediction = [[bor[n] for bor in prediction] for n in range(n_best)]

    return source, target, prediction, confidence, indices


def get_statistical_bleu_predictions(path_data, path, l_in, l_out, n_best, cur_n_best):
    target = []
    try:
        with open(f'{path_data}/test.{l_in}-{l_out}.{l_out}', 'r') as file:
            for i, line in enumerate(file):
                target.append(line.split())
    except FileNotFoundError:
        pass

    source = []
    with open(f'{path_data}/test.{l_in}-{l_out}.{l_in}', 'r') as file:
        for i, line in enumerate(file):
            source.append(line.split())

    prediction = []
    confidence = []
    cur_ix = -1
    cur_prediction = []
    cur_confidence = []
    indices = []
    with open(f'{path}/{l_in}-{l_out}/out/'
              f'test.{l_in}-{l_out}_nbest_{str(n_best)}.{l_out}', 'r') as file:
        for i, line in enumerate(file):
            line = line.split("|||")
            ix = int(line[0])
            word = line[1].strip(' ').split()

            if cur_ix != ix:
                if cur_ix != -1:
                    indices.append(cur_ix)
                    while len(cur_prediction) < cur_n_best:
                        cur_prediction.append(cur_prediction[-1])
                        cur_confidence.append(cur_confidence[-1])
                    prediction.append(cur_prediction)
                    confidence.append(cur_confidence)
                cur_prediction = [word]
                cur_confidence = [math.exp(float(line[-1]))]
                cur_ix = ix
            else:
                cur_prediction.append(word)
                cur_confidence.append(math.exp(float(line[-1])))
        # Management of last prediction
        indices.append(cur_ix)
        while len(cur_prediction) < cur_n_best:
            cur_prediction.append(cur_prediction[-1])
            cur_confidence.append(cur_confidence[-1])
        prediction.append(cur_prediction)
        confidence.append(cur_confidence)

    prediction = [[bor[n] for bor in prediction] for n in range(cur_n_best)]

    return source, target, prediction, confidence, indices

# %% [markdown]
# ## Logic

# %%
def get_results_from_file(langs, model, cur_data):
    cur_results_grouped = {lang: defaultdict(dict) for lang in langs}
    cur_results_by_lang = {lang: defaultdict(dict) for lang in langs}
    # Read results
    for lang_out in langs:
        for lang_in in langs:
            if lang_in == lang_out: continue
            tmp_in = long2short_castrosui[lang_in] if cur_data == "castrosui" else lang_in
            tmp_out = long2short_castrosui[lang_out] if cur_data == "castrosui" else lang_out
            if model == "shared_bilingual":
                all_sources, _, all_predictions, all_confidences, all_indices = get_neural_bleu_predictions(
                    f"{models_dir}/{cur_data}/{model}/{tmp_in}-{tmp_out}/{split}", tmp_in, tmp_out, 10)
            elif model == "shared_multilingual":
                all_sources, _, all_predictions, all_confidences, all_indices = get_neural_bleu_predictions(
                    f"{models_dir}/{cur_data}/{model}/{split}", tmp_in, tmp_out, 10)
            else:
                all_sources, _, all_predictions, all_confidences, all_indices = get_statistical_bleu_predictions(
                    f"{split_data_path}/shared_{cur_data}/{split}",
                    f"{models_dir}/{cur_data}/{model}/{split}", tmp_in, tmp_out, 10, 10)
             
            for ix, (source, index) in enumerate(zip(all_sources, all_indices)):
                predictions = [" ".join(all_predictions[n_best][ix]) for n_best in range(10)]
                confidences = all_confidences[ix]
                cur_results_grouped[lang_out][index].update(
                    {f"{lang_in}_source": " ".join(source),
                     lang_in: sorted([(p, c) for p, c in zip(predictions, confidences)])}
                ) 
                cur_results_by_lang[lang_out][lang_in].update(
                     {" ".join(source): sorted([(p, c) for p, c in zip(predictions, confidences)])}
                ) 
                
                
    return cur_results_grouped, cur_results_by_lang

# %%
def get_best_prediction(row_results):
    predictions_scores = defaultdict(int)
    predictions_counts = defaultdict(int)
    for lang_res in row_results.values():
        for pred, score in lang_res:
            predictions_scores[pred] += score
            predictions_counts[pred] += 1
    # prediction scores is better for SMT models! (considerably)
    best_prediction = [k for k, v in predictions_scores.items() if v == max(predictions_scores.values())]
    if best_prediction:
        best_prediction = best_prediction[0]
    else:
        best_prediction = ""

    return best_prediction

# %%
def reordering(raw_data_path, cur_data, model, split, results_by_lang):
    test_df = pd.read_csv(os.path.join(raw_data_path, cur_data, f"test-{split}.tsv"), sep="\t")
    gold_df = pd.read_csv(os.path.join(raw_data_path, cur_data, f"solutions-{split}.tsv"), sep="\t", index_col="COGID")
    final_results = defaultdict(list)
    for ix, (_, row) in enumerate(test_df.iterrows()):
        row_dict = dict(row)
        cogid = row_dict.pop("COGID")
        lang_out = [k for k, v in row_dict.items() if v == "?"][0]
        gold = gold_df.loc[cogid][lang_out]
        row_total = []
        
        row_results = {}
        # Compute all predictions
        for lang, val in row_dict.items():
            if lang == lang_out: continue            
            if not isinstance(val, str): continue # nan because was empty
            try:
                row_results[lang] = results_by_lang[model][lang_out][lang][val]
            except KeyError: # some chars are only present in test, and encoded as unk
                # We extract possible keys 
                keys_with_unk = [v for v in results_by_lang[model][lang_out][lang].keys() 
                                 if "<unk>" in v and len(v.split(" ")) == len(val.split(" "))]
                possible_keys = []
                for key in keys_with_unk:
                    if sublist_with_unk(key.split(" "), val.split(" ")):
                        possible_keys.append(key)

                if len(possible_keys) > 1:
                    raise Exception("Problem! Several plausible keys!", val, possible_keys)
                elif len(possible_keys) == 0:
                    raise Exception("Problem! No plausible key!", val, lang, lang_out, results_by_lang[model][lang_out])
                else:
                    row_results[lang] = results_by_lang[model][lang_out][lang][possible_keys[0]]
                    
            # This is a gross approximation of the BLEU score - tokenizer should be none, words should be split on char, etc
            # will do for now though
            row_total.extend([(sacrebleu.corpus_bleu(
                [v[0]], [[gold]], tokenize="char", use_effective_order=True).score, v[1]) 
                                 for v in row_results[lang] if 0.3 < len(v[0])/len(val) < 3])


        # Rank best prediction, then Save
        final_results[cogid] = row_total

    return final_results

# %% [markdown]
# # Choosing best answer

# %%
loc_models = ['shared_bilingual', 'shared_multilingual', 'shared_statistical']

# %%
for cur_data in folders:
    for split in splits:
        df = pd.read_csv(os.path.join(raw_data_path, cur_data, f"cognates.tsv"), sep="\t")
        langs = [c for c in df.columns if c != 'COGID']
        results_grouped = {model: {lang: defaultdict(dict) for lang in langs} for model in loc_models}
        results_by_lang = {model: {lang: defaultdict(dict) for lang in langs} for model in loc_models}

        for model in loc_models:
            try:
                # Read results
                cur_results_grouped, cur_results_by_lang = get_results_from_file(langs, model, cur_data)
                results_grouped[model] = cur_results_grouped
                results_by_lang[model] = cur_results_by_lang

                # Reorder according to initial file
                final_results = reordering(raw_data_path, cur_data, model, split, results_by_lang)
                total_bleu2conf = []
                for row in final_results.values():
                    total_bleu2conf.extend(row)
                total_bleu2conf_bleu = [i[0] for i in total_bleu2conf]
                total_bleu2conf_conf = [i[1] for i in total_bleu2conf]

                print(cur_data, split, model, pearsonr(total_bleu2conf_bleu, total_bleu2conf_conf)[0])
            except Exception as e:
                print("ERROR", cur_data, split, model, e)
# Out:
# abrahammonpa 0.10 shared_bilingual 0.23505522855490182
# abrahammonpa 0.10 shared_multilingual 0.16473269356817993
# abrahammonpa 0.10 shared_statistical 0.44790996289724755
# abrahammonpa 0.20 shared_bilingual 0.2154852819570765
# abrahammonpa 0.20 shared_multilingual 0.0925935770372647
# abrahammonpa 0.20 shared_statistical 0.3664352640342917
# abrahammonpa 0.30 shared_bilingual 0.1793040426099256
# abrahammonpa 0.30 shared_multilingual 0.015264590831792818
# abrahammonpa 0.30 shared_statistical 0.28629163457102424
# abrahammonpa 0.40 shared_bilingual 0.04349038820900493
# abrahammonpa 0.40 shared_multilingual -0.04953530205465923
# abrahammonpa 0.40 shared_statistical 0.22666877555138132
# abrahammonpa 0.50 shared_bilingual 0.03133134910556062
# abrahammonpa 0.50 shared_multilingual -0.09576671278302411
# abrahammonpa 0.50 shared_statistical 0.16278401829546715
# allenbai 0.10 shared_bilingual 0.3407190554721396
# ERROR allenbai 0.10 shared_multilingual list index out of range
# allenbai 0.10 shared_statistical 0.39491642131743715
# allenbai 0.20 shared_bilingual 0.3127294420838287
# allenbai 0.20 shared_multilingual 0.2846430532859079
# allenbai 0.20 shared_statistical 0.3894410991748912
# allenbai 0.30 shared_bilingual 0.27899796658296716
# allenbai 0.30 shared_multilingual 0.2710310899093302
# allenbai 0.30 shared_statistical 0.39007590760988525
# allenbai 0.40 shared_bilingual 0.23698213423281256
# allenbai 0.40 shared_multilingual 0.22586111799167977
# allenbai 0.40 shared_statistical 0.35201046672470326
# allenbai 0.50 shared_bilingual 0.21305840811753082
# allenbai 0.50 shared_multilingual 0.17654803229917448
# allenbai 0.50 shared_statistical 0.3251463497945931
# backstromnorthernpakistan 0.10 shared_bilingual 0.3038424503035949
# backstromnorthernpakistan 0.10 shared_multilingual 0.09772154528506095
# backstromnorthernpakistan 0.10 shared_statistical 0.3434942279535011
# backstromnorthernpakistan 0.20 shared_bilingual 0.26511437172955815
# backstromnorthernpakistan 0.20 shared_multilingual 0.006336258200390721
# backstromnorthernpakistan 0.20 shared_statistical 0.29430423346258566
# backstromnorthernpakistan 0.30 shared_bilingual 0.1386290970187286
# backstromnorthernpakistan 0.30 shared_multilingual 0.025443874553190363
# backstromnorthernpakistan 0.30 shared_statistical 0.2606510173694278
# backstromnorthernpakistan 0.40 shared_bilingual 0.1734662265765187
# backstromnorthernpakistan 0.40 shared_multilingual -0.012509822854722187
# backstromnorthernpakistan 0.40 shared_statistical 0.23633526697136553
# backstromnorthernpakistan 0.50 shared_bilingual 0.0974677738790815
# backstromnorthernpakistan 0.50 shared_multilingual -0.05112489224675
# backstromnorthernpakistan 0.50 shared_statistical 0.16588368251156133
# castrosui 0.10 shared_bilingual 0.5376292713033457
# castrosui 0.10 shared_multilingual 0.5314374985633602
# castrosui 0.10 shared_statistical 0.48777637024340936
# castrosui 0.20 shared_bilingual 0.4960690788168704
# ERROR castrosui 0.20 shared_multilingual list index out of range
# castrosui 0.20 shared_statistical 0.47088171635535553
# castrosui 0.30 shared_bilingual 0.4270152155363288
# ERROR castrosui 0.30 shared_multilingual list index out of range
# castrosui 0.30 shared_statistical 0.4377719206704446
# castrosui 0.40 shared_bilingual 0.3381720490643137
# ERROR castrosui 0.40 shared_multilingual list index out of range
# castrosui 0.40 shared_statistical 0.3803632726750566
# ERROR castrosui 0.50 shared_bilingual ('Problem! Several plausible keys!', 'pʰ uː t ¹', ['pʰ <unk> t ¹', 'p <unk> t ¹'])
# ERROR castrosui 0.50 shared_multilingual list index out of range
# castrosui 0.50 shared_statistical 0.2972351194952138
# davletshinaztecan 0.10 shared_bilingual 0.22608620555938921
# davletshinaztecan 0.10 shared_multilingual 0.02448669842089184
# davletshinaztecan 0.10 shared_statistical 0.2679649455984709
# ERROR davletshinaztecan 0.20 shared_bilingual list index out of range
# davletshinaztecan 0.20 shared_multilingual 0.025106605644586166
# davletshinaztecan 0.20 shared_statistical 0.15078136454593408
# davletshinaztecan 0.30 shared_bilingual 0.06792301539247864
# davletshinaztecan 0.30 shared_multilingual -0.015171272438290978
# davletshinaztecan 0.30 shared_statistical 0.1699622786103345
# davletshinaztecan 0.40 shared_bilingual 0.023175482437797063
# davletshinaztecan 0.40 shared_multilingual -0.013677711602410065
# davletshinaztecan 0.40 shared_statistical 0.17044487719462487
# davletshinaztecan 0.50 shared_bilingual 0.04115431020139515
# davletshinaztecan 0.50 shared_multilingual 0.012581068992614422
# davletshinaztecan 0.50 shared_statistical 0.09896185884815845
# felekesemitic 0.10 shared_bilingual 0.12460073119300451
# ERROR felekesemitic 0.10 shared_multilingual list index out of range
# felekesemitic 0.10 shared_statistical 0.16998458565510946
# felekesemitic 0.20 shared_bilingual 0.1317574704440002
# ERROR felekesemitic 0.20 shared_multilingual list index out of range
# felekesemitic 0.20 shared_statistical 0.17343947569008156
# ERROR felekesemitic 0.30 shared_bilingual list index out of range
# ERROR felekesemitic 0.30 shared_multilingual list index out of range
# ERROR felekesemitic 0.30 shared_statistical [Errno 2] No such file or directory: '/home/cfourrie/documents/software/public/CopperMT/workspace/felekesemitic/shared_statistical/0.30/Tigrigna-Gura/out/test.Tigrigna-Gura_nbest_10.Gura'
# ERROR felekesemitic 0.40 shared_bilingual list index out of range
# ERROR felekesemitic 0.40 shared_multilingual list index out of range
# ERROR felekesemitic 0.40 shared_statistical [Errno 2] No such file or directory: '/home/cfourrie/documents/software/public/CopperMT/workspace/felekesemitic/shared_statistical/0.40/Endegagn-Amharic/out/test.Endegagn-Amharic_nbest_10.Amharic'
# ERROR felekesemitic 0.50 shared_bilingual list index out of range
# ERROR felekesemitic 0.50 shared_multilingual list index out of range
# ERROR felekesemitic 0.50 shared_statistical [Errno 2] No such file or directory: '/home/cfourrie/documents/software/public/CopperMT/workspace/felekesemitic/shared_statistical/0.50/Chaha-Amharic/out/test.Chaha-Amharic_nbest_10.Amharic'
# hantganbangime 0.10 shared_bilingual 0.20317220766050328
# ERROR hantganbangime 0.10 shared_multilingual list index out of range
# hantganbangime 0.10 shared_statistical 0.2387543511963726
# hantganbangime 0.20 shared_bilingual 0.18578668543793364
# ERROR hantganbangime 0.20 shared_multilingual list index out of range
# hantganbangime 0.20 shared_statistical 0.1405176388204523
# hantganbangime 0.30 shared_bilingual 0.09580917839625581
# ERROR hantganbangime 0.30 shared_multilingual list index out of range
# hantganbangime 0.30 shared_statistical 0.12714789927602518
# ERROR hantganbangime 0.40 shared_bilingual list index out of range
# ERROR hantganbangime 0.40 shared_multilingual list index out of range
# ERROR hantganbangime 0.40 shared_statistical [Errno 2] No such file or directory: '/home/cfourrie/documents/software/public/CopperMT/workspace/hantganbangime/shared_statistical/0.40/Toro_Tegu-Bunoge/out/test.Toro_Tegu-Bunoge_nbest_10.Bunoge'
# ERROR hantganbangime 0.50 shared_bilingual list index out of range
# ERROR hantganbangime 0.50 shared_multilingual list index out of range
# ERROR hantganbangime 0.50 shared_statistical [Errno 2] No such file or directory: '/home/cfourrie/documents/software/public/CopperMT/workspace/hantganbangime/shared_statistical/0.50/Bunoge-Bankan_Tey/out/test.Bunoge-Bankan_Tey_nbest_10.Bankan_Tey'
# hattorijaponic 0.10 shared_bilingual 0.2620186394212769
# hattorijaponic 0.10 shared_multilingual 0.0834712440090482
# hattorijaponic 0.10 shared_statistical 0.23630455401646686
# hattorijaponic 0.20 shared_bilingual 0.23780168081539116
# hattorijaponic 0.20 shared_multilingual 0.03432881067057472
# hattorijaponic 0.20 shared_statistical 0.2619543828570404
# hattorijaponic 0.30 shared_bilingual 0.23955337360520002
# hattorijaponic 0.30 shared_multilingual 0.04072833882201654
# hattorijaponic 0.30 shared_statistical 0.25172216068615794
# hattorijaponic 0.40 shared_bilingual 0.15229384412863864
# hattorijaponic 0.40 shared_multilingual 0.0036145956276504142
# ERROR hattorijaponic 0.40 shared_statistical ('Problem! No plausible key!', 'm i r u', 'Kochi', 'Amami', defaultdict(<class 'dict'>, {'Hachijo': {'k o r e': [('k r u ɴ', 0.0018224017591113692), ('k u r x i', 0.00283050539065717), ('k u r ɴ', 0.002203275857459589), ('k u x', 0.0024787273892685298), ('k u ɴ', 0.01860081280545042), ('x u r x i', 0.0031228476034458287), ('x u r ɴ', 0.0024308361163729347), ('x u x', 0.0018831111554659936), ('x u ɴ', 0.014131202263841913), ('ʔ u ɴ', 0.007658646561042101)], 'd a r e': [('d a r i r x i', 2.672232533039734e-46), ('d a r i r ɴ', 2.0811367892802283e-46), ('d a r i ɴ', 2.3867062508679314e-46), ('d a r x', 1.285199909350386e-46), ('d a r x i', 3.769394120214446e-46), ('d a r ɴ', 2.9326729527496188e-46), ('d a x', 4.878873132487493e-46), ('d a x i', 3.4656987706663344e-46), ('d a ɴ', 2.255404158771999e-45), ('ɴ d a r i', 1.3309783558707632e-46)], 't eː ts u': [('eː ts ɨ u r', 8.183209750726699e-48), ('eː u r ts ɨ', 1.457174622453291e-47), ('ts ɨ eː u r', 7.352824048492542e-48), ('ts ɨ u r eː', 4.4021121670739104e-48), ('ts ɨ u r eː', 4.4021121670739104e-48), ('ts ɨ u r eː', 4.4021121670739104e-48), ('ts ɨ u r eː', 4.4021121670739104e-48), ('ts ɨ u r eː', 4.4021121670739104e-48), ('u r eː ts ɨ', 4.057225520681513e-47), ('u r ts ɨ eː', 5.847910767608566e-48)], 'h u t a ts u': [('h a r i ts ɨ u r u r i', 0.00015191642862461926), ('h a ts ɨ u r i', 0.00019131868738709757), ('h a ts ɨ u r u r i', 0.0003551607692064135), ('h u r i u r a ts ɨ', 0.00019160013266915756), ('h u r u r a ts ɨ', 0.0002247818908290248), ('h u u r a ts ɨ', 0.00037356445425242854), ('h ɨ r u r a ts ɨ', 0.00037483298670000145), ('h ɨ r u r i u r a ts ɨ', 0.00016723676418413548), ('h ɨ r u r u r a ts ɨ', 0.00019619921732699807), ('w a ts ɨ u r u r i', 0.0002626705428080362)], 'n a g a kʲ a': [('e a g a s a r i', 0.004286563139947597), ('g e a g a s a r i', 0.0035712842999471093), ('n a g a r i s a r i', 0.007503017545174858), ('n a g a r s a r i', 0.005082916845429986), ('n a g a s a', 0.004730804530156228), ('n a g a s a r', 0.002363055013117289), ('n a g a s a r i', 0.02261775639488931), ('n a o a r i s a r i', 0.002403930915583928), ('n a o a s a r i', 0.007246620911047506), ('n a r i g a s a r i', 0.0032087943637748033)], 't o r i m e': [('m u r u r i x i', 9.890309753079762e-05), ('m u r u r i ɴ', 5.9443159769037626e-05), ('m x i u r u r i', 5.496851451583292e-05), ('m x u r u r i', 0.00016589093559902886), ('m ɴ g u r u r i', 6.533321491036257e-05), ('m ɴ u r u r i', 8.101226459506533e-05), ('u r u r i m x', 0.00011645216152233104), ('u r u r i m x i', 0.0003412722541380716), ('u r u r i m ɴ', 0.000265647583942121), ('u r u r i m ɴ g', 6.459329145590808e-05)], 'ɕ a ɴ m e': [('m x i ɕ a ɴ', 4.089813502973729e-47), ('m x ɕ a ɴ', 1.922255758665946e-47), ('m ɴ ɕ a ɴ', 2.163006972980808e-47), ('ɕ a r i ɴ m x i', 5.005310109161325e-47), ('ɕ a r i ɴ m ɴ', 3.898139432530059e-47), ('ɕ a r ɴ m x i', 2.000704504372864e-47), ('ɕ a ɴ m x', 3.5236569998588804e-47), ('ɕ a ɴ m x i', 1.0334619447362126e-46), ('ɕ a ɴ m ɴ', 8.040565131595964e-47), ('ɕ a ɴ m ɴ g', 1.9552134532398157e-47)], 'k i': [('i k', 0.0014827304385722085), ('i x', 0.001876625615968113), ('i ʔ', 0.0006744452883415263), ('i ʔ', 0.0006744452883415263), ('i ʔ', 0.0006744452883415263), ('i ʔ', 0.0006744452883415263), ('i ʔ', 0.0006744452883415263), ('k i', 0.4324152178148474), ('x i', 0.12272367445909968), ('ʔ i', 0.06107699485435381)], 'h a': [('a h', 0.001731650983204221), ('a r i h', 0.001200424541706303), ('h a', 0.5075449502841443), ('h a r', 0.07839775399963303), ('h a r i', 0.8619577702049614), ('h ɴ', 0.011717287073486297), ('w a', 0.32452263234014117), ('w a r', 0.05819417588247549), ('w a r i', 0.6398266491633916), ('w ɴ', 0.004464803832988022)], 'n e': [('e x i', 0.005808052280712903), ('e ɴ', 0.004521054571826934), ('g e x i', 0.004838938018473211), ('n x i', 0.01122805187889737), ('n ɴ', 0.008739957080715802), ('x e', 0.007875489007561841), ('x g e', 0.01062 ...
# hattorijaponic 0.50 shared_bilingual -0.044711501958247954
# hattorijaponic 0.50 shared_multilingual 0.00044876194525827486
# hattorijaponic 0.50 shared_statistical 0.21123349611612316
# listsamplesize 0.10 shared_bilingual 0.3466062191379084
# listsamplesize 0.10 shared_multilingual 0.19822395407154558
# listsamplesize 0.10 shared_statistical 0.331472928213488
# listsamplesize 0.20 shared_bilingual 0.24140977006800246
# listsamplesize 0.20 shared_multilingual 0.11025532981301045
# listsamplesize 0.20 shared_statistical 0.22632892221752535
# listsamplesize 0.30 shared_bilingual 0.2102263285513636
# listsamplesize 0.30 shared_multilingual 0.14148683748295626
# listsamplesize 0.30 shared_statistical 0.29389703512280324
# listsamplesize 0.40 shared_bilingual 0.2771069199696752
# listsamplesize 0.40 shared_multilingual 0.08116543616471106
# listsamplesize 0.40 shared_statistical 0.27599959038637695
# listsamplesize 0.50 shared_bilingual 0.2582503991663772
# listsamplesize 0.50 shared_multilingual 0.044197922980569654
# listsamplesize 0.50 shared_statistical 0.2999502138678195
# mannburmish 0.10 shared_bilingual 0.11790002175732928
# mannburmish 0.10 shared_multilingual 0.052214752325984944
# mannburmish 0.10 shared_statistical 0.26157622348809456
# mannburmish 0.20 shared_bilingual 0.17697397758915803
# mannburmish 0.20 shared_multilingual 0.06590907537830554
# mannburmish 0.20 shared_statistical 0.2523166248324453
# ERROR mannburmish 0.30 shared_bilingual [Errno 2] No such file or directory: '/home/cfourrie/documents/software/public/CopperMT/workspace/mannburmish/shared_bilingual/WrittenBurmese-Achang/0.30/bleu/bleu_checkpoint_best_WrittenBurmese-Achang.Achang'
# ERROR mannburmish 0.30 shared_multilingual ('Problem! Several plausible keys!', 'tsʰ uː', ['t <unk>', 'tsʰ <unk>'])
# mannburmish 0.30 shared_statistical 0.18782115484394057
# ERROR mannburmish 0.40 shared_bilingual [Errno 2] No such file or directory: '/home/cfourrie/documents/software/public/CopperMT/workspace/mannburmish/shared_bilingual/Bela-Achang/0.40/bleu/bleu_checkpoint_best_Bela-Achang.Achang'
# ERROR mannburmish 0.40 shared_multilingual ('Problem! Several plausible keys!', 'tsʰ uː', ['tsʰ <unk>', 't <unk>'])
# mannburmish 0.40 shared_statistical 0.12357802825477165
# ERROR mannburmish 0.50 shared_bilingual [Errno 2] No such file or directory: '/home/cfourrie/documents/software/public/CopperMT/workspace/mannburmish/shared_bilingual/Bela-Achang/0.50/bleu/bleu_checkpoint_best_Bela-Achang.Achang'
# ERROR mannburmish 0.50 shared_multilingual ('Problem! Several plausible keys!', 'tsʰ uː', ['tsʰ <unk>', 't <unk>'])
# mannburmish 0.50 shared_statistical 0.09866290496870041

# %% [markdown]
# ```bash
# source ~/Desktop/SIGTYP2022/venv/bin/activate
# # Baseline
# #model="backstromnorthernpakistan"
# for model in "abrahammonpa" "allenbai" "backstromnorthernpakistan" "castrosui" "davletshinaztecan" "felekesemitic" "hantganbangime" "hattorijaponic" "listsamplesize" "mannburmish"; do
#     echo ")0.10 - baseline" >> analysis_${model}.txt;
#     st2022 --compare --prediction-file=${model}/result-0.10.tsv --solution-file=${model}/solutions-0.10.tsv >> analysis_${model}.txt;
#     echo ")0.10 - BiNMT" >> analysis_${model}.txt;
#     st2022 --compare --prediction-file=${model}/results-shared_bilingual-0.10.tsv --solution-file=${model}/solutions-0.10.tsv  >> analysis_${model}.txt;
#     echo ")0.10 - MNMT" >> analysis_${model}.txt;
#     st2022 --compare --prediction-file=${model}/results-shared_multilingual-0.10.tsv --solution-file=${model}/solutions-0.10.tsv  >> analysis_${model}.txt;
#     echo ")0.10 - SMT" >> analysis_${model}.txt;
#     st2022 --compare --prediction-file=${model}/results-shared_statistical-0.10.tsv --solution-file=${model}/solutions-0.10.tsv  >> analysis_${model}.txt;
#
#     echo ")0.50 - baseline" >> analysis_${model}.txt;
#     st2022 --compare --prediction-file=${model}/result-0.50.tsv --solution-file=${model}/solutions-0.50.tsv  >> analysis_${model}.txt;
#     echo ")0.50 - BiNMT" >> analysis_${model}.txt;
#     st2022 --compare --prediction-file=${model}/results-shared_bilingual-0.50.tsv --solution-file=${model}/solutions-0.50.tsv >> analysis_${model}.txt;
#     echo ")0.50 - MNMT" >> analysis_${model}.txt;
#     st2022 --compare --prediction-file=${model}/results-shared_multilingual-0.50.tsv --solution-file=${model}/solutions-0.50.tsv  >> analysis_${model}.txt;
#     echo ")0.50 - SMT" >> analysis_${model}.txt;
#     st2022 --compare --prediction-file=${model}/results-shared_statistical-0.50.tsv --solution-file=${model}/solutions-0.50.tsv >> analysis_${model}.txt;
# done
# ```

# %% [markdown]
# ## Problems to manage
# - sur allenbai encoding en 0.10 pour bilingue et multilingue
# - castrosui languages changes for saves, need to change them when called here too
# - davletshinaztecan 0.20 bilingual not launched for all language pairs?

# %%
results_dict = {language_family: {split: {
    model: {} for model in models
} for split in splits} for language_family in folders}

for language_family in folders:
    cur_model = "baseline"
    cur_split = "0.10"
    with open(os.path.join(copper_dir, raw_data_path, f"analysis_{language_family}.txt"), "r") as f: 
        for line in f:
            if "Language" in line: continue
            if "--" in line: continue
            if line[0] == ")":
                cur_split, cur_model = line[1:].replace("\n", "").split(" - ");
                continue
            lang, ed, norm_ed, f5 = " ".join(line.split()).split()
            results_dict[language_family][cur_split][cur_model].update(
                {lang: {"ED": ed, "Normalized ED": norm_ed, "B2 F5": f5}}
            )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4330/2539504226.py in <module>
#      14                 continue
#      15             lang, ed, norm_ed, f5 = " ".join(line.split()).split()
# ---> 16             results_dict[language_family][cur_split][cur_model].update(
#      17                 {lang: {"ED": ed, "Normalized ED": norm_ed, "B2 F5": f5}}
#      18             )
#
# KeyError: 'O.10'

# %%
models
# Out:
# ['shared_bilingual', 'shared_multilingual', 'shared_statistical']

# %%
for k, v in results_dict.items():
    for split in ["0.10", "0.50"]:
        for model in models:
            try:
                print(k, split, v[split][model]["TOTAL"])
            except KeyError:
                print(k, model, split)
# Out:
# abrahammonpa 0.10 {'ED': '0.459', 'Normalized ED': '0.088', 'B2 F5': '0.884'}
# abrahammonpa 0.10 {'ED': '1.150', 'Normalized ED': '0.223', 'B2 F5': '0.712'}
# abrahammonpa 0.10 {'ED': '1.041', 'Normalized ED': '0.194', 'B2 F5': '0.725'}
# abrahammonpa 0.10 {'ED': '0.372', 'Normalized ED': '0.069', 'B2 F5': '0.900'}
# abrahammonpa 0.50 {'ED': '1.486', 'Normalized ED': '0.281', 'B2 F5': '0.687'}
# abrahammonpa 0.50 {'ED': '3.483', 'Normalized ED': '0.657', 'B2 F5': '0.285'}
# abrahammonpa 0.50 {'ED': '3.694', 'Normalized ED': '0.675', 'B2 F5': '0.249'}
# abrahammonpa 0.50 {'ED': '0.961', 'Normalized ED': '0.168', 'B2 F5': '0.724'}
# allenbai baseline 0.10
# allenbai BiNMT 0.10
# allenbai MNMT 0.10
# allenbai SMT 0.10
# allenbai baseline 0.50
# allenbai BiNMT 0.50
# allenbai MNMT 0.50
# allenbai SMT 0.50
# backstromnorthernpakistan baseline 0.10
# backstromnorthernpakistan BiNMT 0.10
# backstromnorthernpakistan MNMT 0.10
# backstromnorthernpakistan SMT 0.10
# backstromnorthernpakistan baseline 0.50
# backstromnorthernpakistan BiNMT 0.50
# backstromnorthernpakistan MNMT 0.50
# backstromnorthernpakistan SMT 0.50
# castrosui baseline 0.10
# castrosui BiNMT 0.10
# castrosui MNMT 0.10
# castrosui SMT 0.10
# castrosui baseline 0.50
# castrosui BiNMT 0.50
# castrosui MNMT 0.50
# castrosui SMT 0.50
# davletshinaztecan baseline 0.10
# davletshinaztecan BiNMT 0.10
# davletshinaztecan MNMT 0.10
# davletshinaztecan SMT 0.10
# davletshinaztecan baseline 0.50
# davletshinaztecan BiNMT 0.50
# davletshinaztecan MNMT 0.50
# davletshinaztecan SMT 0.50
# felekesemitic baseline 0.10
# felekesemitic BiNMT 0.10
# felekesemitic MNMT 0.10
# felekesemitic SMT 0.10
# felekesemitic baseline 0.50
# felekesemitic BiNMT 0.50
# felekesemitic MNMT 0.50
# felekesemitic SMT 0.50
# hantganbangime baseline 0.10
# hantganbangime BiNMT 0.10
# hantganbangime MNMT 0.10
# hantganbangime SMT 0.10
# hantganbangime baseline 0.50
# hantganbangime BiNMT 0.50
# hantganbangime MNMT 0.50
# hantganbangime SMT 0.50
# hattorijaponic baseline 0.10
# hattorijaponic BiNMT 0.10
# hattorijaponic MNMT 0.10
# hattorijaponic SMT 0.10
# hattorijaponic baseline 0.50
# hattorijaponic BiNMT 0.50
# hattorijaponic MNMT 0.50
# hattorijaponic SMT 0.50
# listsamplesize baseline 0.10
# listsamplesize BiNMT 0.10
# listsamplesize MNMT 0.10
# listsamplesize SMT 0.10
# listsamplesize baseline 0.50
# listsamplesize BiNMT 0.50
# listsamplesize MNMT 0.50
# listsamplesize SMT 0.50
# mannburmish baseline 0.10
# mannburmish BiNMT 0.10
# mannburmish MNMT 0.10
# mannburmish SMT 0.10
# mannburmish baseline 0.50
# mannburmish BiNMT 0.50
# mannburmish MNMT 0.50
# mannburmish SMT 0.50

# %%
for k, v in results_dict.items():
    for split in ["0.10", "0.50"]:
        for model in models:
            try:
                print(k, split, v[split][model]["TOTAL"])
            except KeyError:
                print(k, model, split)
# Out:
# abrahammonpa 0.10 {'ED': '0.459', 'Normalized ED': '0.088', 'B2 F5': '0.884'}
# abrahammonpa 0.10 {'ED': '1.150', 'Normalized ED': '0.223', 'B2 F5': '0.712'}
# abrahammonpa 0.10 {'ED': '1.041', 'Normalized ED': '0.194', 'B2 F5': '0.725'}
# abrahammonpa 0.10 {'ED': '0.372', 'Normalized ED': '0.069', 'B2 F5': '0.900'}
# abrahammonpa 0.50 {'ED': '1.486', 'Normalized ED': '0.281', 'B2 F5': '0.687'}
# abrahammonpa 0.50 {'ED': '3.483', 'Normalized ED': '0.657', 'B2 F5': '0.285'}
# abrahammonpa 0.50 {'ED': '3.694', 'Normalized ED': '0.675', 'B2 F5': '0.249'}
# abrahammonpa 0.50 {'ED': '0.961', 'Normalized ED': '0.168', 'B2 F5': '0.724'}
# allenbai 0.10 {'ED': '0.882', 'Normalized ED': '0.288', 'B2 F5': '0.743'}
# allenbai BiNMT 0.10
# allenbai MNMT 0.10
# allenbai SMT 0.10
# allenbai 0.50 {'ED': '1.192', 'Normalized ED': '0.379', 'B2 F5': '0.637'}
# allenbai 0.50 {'ED': '1.273', 'Normalized ED': '0.406', 'B2 F5': '0.499'}
# allenbai 0.50 {'ED': '1.206', 'Normalized ED': '0.386', 'B2 F5': '0.519'}
# allenbai 0.50 {'ED': '0.856', 'Normalized ED': '0.276', 'B2 F5': '0.642'}
# backstromnorthernpakistan 0.10 {'ED': '1.389', 'Normalized ED': '0.288', 'B2 F5': '0.805'}
# backstromnorthernpakistan 0.10 {'ED': '1.520', 'Normalized ED': '0.310', 'B2 F5': '0.689'}
# backstromnorthernpakistan 0.10 {'ED': '1.949', 'Normalized ED': '0.402', 'B2 F5': '0.600'}
# backstromnorthernpakistan 0.10 {'ED': '0.497', 'Normalized ED': '0.102', 'B2 F5': '0.881'}
# backstromnorthernpakistan 0.50 {'ED': '1.596', 'Normalized ED': '0.354', 'B2 F5': '0.689'}
# backstromnorthernpakistan 0.50 {'ED': '2.956', 'Normalized ED': '0.656', 'B2 F5': '0.334'}
# backstromnorthernpakistan 0.50 {'ED': '3.283', 'Normalized ED': '0.694', 'B2 F5': '0.264'}
# backstromnorthernpakistan 0.50 {'ED': '0.643', 'Normalized ED': '0.142', 'B2 F5': '0.803'}
# castrosui 0.10 {'ED': '0.311', 'Normalized ED': '0.079', 'B2 F5': '0.920'}
# castrosui BiNMT 0.10
# castrosui MNMT 0.10
# castrosui SMT 0.10
# castrosui 0.50 {'ED': '0.692', 'Normalized ED': '0.175', 'B2 F5': '0.842'}
# castrosui BiNMT 0.50
# castrosui MNMT 0.50
# castrosui SMT 0.50
# davletshinaztecan 0.10 {'ED': '3.694', 'Normalized ED': '0.550', 'B2 F5': '0.529'}
# davletshinaztecan 0.10 {'ED': '3.231', 'Normalized ED': '0.565', 'B2 F5': '0.494'}
# davletshinaztecan 0.10 {'ED': '3.778', 'Normalized ED': '0.639', 'B2 F5': '0.445'}
# davletshinaztecan 0.10 {'ED': '1.833', 'Normalized ED': '0.296', 'B2 F5': '0.658'}
# davletshinaztecan 0.50 {'ED': '3.891', 'Normalized ED': '0.568', 'B2 F5': '0.476'}
# davletshinaztecan 0.50 {'ED': '4.695', 'Normalized ED': '0.753', 'B2 F5': '0.264'}
# davletshinaztecan 0.50 {'ED': '4.645', 'Normalized ED': '0.699', 'B2 F5': '0.274'}
# davletshinaztecan 0.50 {'ED': '2.229', 'Normalized ED': '0.362', 'B2 F5': '0.559'}
# felekesemitic 0.10 {'ED': '2.165', 'Normalized ED': '0.394', 'B2 F5': '0.596'}
# felekesemitic 0.10 {'ED': '3.569', 'Normalized ED': '0.679', 'B2 F5': '0.355'}
# felekesemitic MNMT 0.10
# felekesemitic 0.10 {'ED': '1.650', 'Normalized ED': '0.302', 'B2 F5': '0.649'}
# felekesemitic 0.50 {'ED': '5.074', 'Normalized ED': '0.842', 'B2 F5': '0.281'}
# felekesemitic BiNMT 0.50
# felekesemitic MNMT 0.50
# felekesemitic SMT 0.50
# hantganbangime 0.10 {'ED': '1.920', 'Normalized ED': '0.471', 'B2 F5': '0.521'}
# hantganbangime 0.10 {'ED': '2.656', 'Normalized ED': '0.664', 'B2 F5': '0.322'}
# hantganbangime MNMT 0.10
# hantganbangime 0.10 {'ED': '1.368', 'Normalized ED': '0.340', 'B2 F5': '0.579'}
# hantganbangime 0.50 {'ED': '3.614', 'Normalized ED': '0.838', 'B2 F5': '0.245'}
# hantganbangime BiNMT 0.50
# hantganbangime MNMT 0.50
# hantganbangime SMT 0.50
# hattorijaponic 0.10 {'ED': '1.739', 'Normalized ED': '0.346', 'B2 F5': '0.700'}
# hattorijaponic 0.10 {'ED': '1.214', 'Normalized ED': '0.265', 'B2 F5': '0.695'}
# hattorijaponic 0.10 {'ED': '1.893', 'Normalized ED': '0.385', 'B2 F5': '0.547'}
# hattorijaponic 0.10 {'ED': '0.786', 'Normalized ED': '0.171', 'B2 F5': '0.807'}
# hattorijaponic 0.50 {'ED': '2.208', 'Normalized ED': '0.423', 'B2 F5': '0.582'}
# hattorijaponic 0.50 {'ED': '3.599', 'Normalized ED': '0.750', 'B2 F5': '0.251'}
# hattorijaponic 0.50 {'ED': '3.332', 'Normalized ED': '0.643', 'B2 F5': '0.290'}
# hattorijaponic 0.50 {'ED': '1.536', 'Normalized ED': '0.290', 'B2 F5': '0.635'}
# listsamplesize 0.10 {'ED': '4.007', 'Normalized ED': '0.685', 'B2 F5': '0.401'}
# listsamplesize 0.10 {'ED': '2.708', 'Normalized ED': '0.560', 'B2 F5': '0.444'}
# listsamplesize 0.10 {'ED': '3.241', 'Normalized ED': '0.612', 'B2 F5': '0.401'}
# listsamplesize 0.10 {'ED': '2.379', 'Normalized ED': '0.473', 'B2 F5': '0.541'}
# listsamplesize 0.50 {'ED': '4.295', 'Normalized ED': '0.776', 'B2 F5': '0.327'}
# listsamplesize 0.50 {'ED': '3.300', 'Normalized ED': '0.703', 'B2 F5': '0.258'}
# listsamplesize 0.50 {'ED': '3.624', 'Normalized ED': '0.760', 'B2 F5': '0.225'}
# listsamplesize 0.50 {'ED': '2.621', 'Normalized ED': '0.494', 'B2 F5': '0.448'}
# mannburmish 0.10 {'ED': '2.729', 'Normalized ED': '0.666', 'B2 F5': '0.454'}
# mannburmish BiNMT 0.10
# mannburmish MNMT 0.10
# mannburmish 0.10 {'ED': '1.786', 'Normalized ED': '0.461', 'B2 F5': '0.523'}
# mannburmish 0.50 {'ED': '3.087', 'Normalized ED': '0.744', 'B2 F5': '0.288'}
# mannburmish BiNMT 0.50
# mannburmish MNMT 0.50
# mannburmish 0.50 {'ED': '2.517', 'Normalized ED': '0.634', 'B2 F5': '0.308'}
